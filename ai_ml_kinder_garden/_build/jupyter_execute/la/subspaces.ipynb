# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Subspaces

# %% [markdown]
# ## Linear Subspaces
# :::{card}
# $\mathbb{R^2}$ - All 2D vectors $\hat V = (x, y)$
#
# $\mathbb{R^3}$ - All 3D vectors $\hat V = (x, y, z)$
#
# .
#
# .
#
# .
#
# $\mathbb{R^n}$ - All nD vectors $\hat V = (v_1, v_2, ..., v_n)$
# :::
#
# ### Properties
# :::{card}
# 1. Include Zero Vector
#
# - If a linear subspace doesn't include a zero vector , it is not a subspace.
#
# 2. Closed under scalar multiplication
#
# - If multiplication of a scalar results in a vector which is not part of subspace, it is not a subspace.
#
# 3. Closed under addition
#
# - Adding any 2 vectors $V_1, V_2 | \: s.t \: V_1, V_2 \in S \implies V_1 + V_2 \in S$
# :::

# %% [markdown]
# ### Spans as Subspaces
#
# A span always result in a subspace of linear comnination of the vectors of the span.
#
#
# ### Basis
#
# A subspace that is Linearly Independent and spans the subspace form a set of basis vectors.

# %%
# Define vectors
v1 = np.array([1, 2])
v2 = np.array([3, 1])

# Create a grid for span visualization
x = np.linspace(-5, 5, 20)
y1 = (v1[1] / v1[0]) * x
y2 = (v2[1] / v2[0]) * x

# Create figure and axis
fig, ax = plt.subplots(figsize=(8, 8))

# Plot the vectors
ax.quiver(0, 0, v1[0], v1[1], angles='xy', scale_units='xy', scale=1, color='r', label='${v}_1$')
ax.quiver(0, 0, v2[0], v2[1], angles='xy', scale_units='xy', scale=1, color='b', label='${v}_2$')

# Plot lines representing span of the vectors
ax.plot(x, y1, 'r--', label='Span of ${v}_1$')
ax.plot(x, y2, 'b--', label='Span of ${v}_2$')

# Fill area to show span
x_fill = np.linspace(-5, 5, 200)
y_fill = (v1[1] / v1[0]) * x_fill + (v2[1] / v2[0]) * x_fill
ax.fill_between(x_fill, y_fill - 1, y_fill + 1, color='gray', alpha=0.2, label='Span Area')

# Set plot limits and labels
ax.set_xlim(-5, 5)
ax.set_ylim(-5, 5)
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.axhline(0, color='black',linewidth=0.5)
ax.axvline(0, color='black',linewidth=0.5)
ax.grid(True, linestyle='--', alpha=0.7)
ax.legend()
ax.set_title('Span and Basis in 2D')

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

# Define vectors
v1 = np.array([1, 2, 3])
v2 = np.array([4, 5, 6])

# Create a grid for span visualization
u = np.linspace(-1, 1, 10)
v = np.linspace(-1, 1, 10)
U, V = np.meshgrid(u, v)
X = U * v1[0] + V * v2[0]
Y = U * v1[1] + V * v2[1]
Z = U * v1[2] + V * v2[2]

# Create figure and 3D axis
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot the vectors
ax.quiver(0, 0, 0, v1[0], v1[1], v1[2], color='r', label='${v}_1$')
ax.quiver(0, 0, 0, v2[0], v2[1], v2[2], color='b', label='${v}_2$')

# Plot the plane representing the span of the vectors
ax.plot_surface(X, Y, Z, color='gray', alpha=0.5, rstride=100, cstride=100)

# Set plot labels
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.set_zlabel('$z$')
ax.set_title('Span and Basis in 3D')
ax.legend()

plt.show()
